# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !pip3 install ipympl
# Out:
# Requirement already satisfied: ipympl in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (0.9.2)
# Requirement already satisfied: ipython-genutils in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipympl) (3.6.3)
# Requirement already satisfied: pillow in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: numpy in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipympl) (1.23.1)
# Requirement already satisfied: ipython<9 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipympl) (8.4.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipympl) (8.0.4)
# Requirement already satisfied: traitlets<6 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipympl) (5.3.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (58.1.0)
# Requirement already satisfied: backcall in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (2.12.0)
# Requirement already satisfied: appnope in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (3.0.30)
# Requirement already satisfied: jedi>=0.16 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: stack-data in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (0.3.0)
# Requirement already satisfied: pickleshare in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipython<9->ipympl) (0.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.15.1)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.5)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: nest-asyncio in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.2)
# Requirement already satisfied: pyzmq>=17 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.3.4)
# Requirement already satisfied: psutil in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from pexpect>4.3->ipython<9->ipympl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.9.1)
# Requirement already satisfied: asttokens in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: entrypoints in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/pitosalas/.pyenv/versions/3.10.5/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (4.11.1)
#
# [notice] A new release of pip available: 22.2.2 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# Read in raw data file into pandas

# %%
filename = "scan1.csv"
df = pd.read_csv(filename)

# %% [markdown]
# Turn the scan columns into a numpy array

# %%
range_cols = [col for col in df.columns if 'ranges' in col]
nparr = df[range_cols].to_numpy()

# %% [markdown]
# Grab each group of N columns into a new single column which is an average. This reduces noise. This function will take a single row (list) and distill it by averaging groups of N values.

# %%
def distill(a):
    N = 5
    limit0 = N * (a.size//N)
    out = np.zeros((a.size + N -1)//N)
    out[:limit0//N] = a[:limit0].reshape(-1,N).mean(1)
    out[limit0//N:] = a[limit0:].mean()
    return out

# %% [markdown]
# Now apply it to all the readings. We end up with a list of lists. First dimension is the reading, and second dimension is the angle.

# %%
readings = [distill(a) for a in nparr]
readings = np.array(readings)

# %% [markdown]
# Filter all cells to reflect whether they are a good reading or not.

# %%
low_limit = 0.05
high_limit = 25.0
readings_mask = (readings > low_limit) & (readings < high_limit)

# %% [markdown]
# Visualize it as a circle

# %%
# %matplotlib widget
import numpy as np
import matplotlib.pyplot as plt
  
# setting the axes projection as polar
plt.axes(projection = 'polar')
  
# setting the radius
r = 3
# creating an array containing the
# radian values

rads = np.arange(0, (2 * np.pi), 2 * np.pi / readings_mask[0].size)

# Indicate directions: green is forward, red is backward, yellow is 90 degrees. This helps understand
# the graph
plt.polar(0, 4, 'go')
plt.polar(np.pi, 4, 'ro')
plt.polar(np.pi/2, 4, 'yp')

# plotting the data
for rad in np.arange(0, readings_mask.shape[1]):
    for read in range(0, readings_mask.shape[0]):
        angle = rad * (2 * np.pi)/readings_mask.shape[1]
        plt.polar(angle, 8+read/10.0 if readings_mask[read, rad] else 0, markersize=2, marker='.', color='red')
        plt.polar(angle, 2+readings[read, rad], marker='.', markersize=4, color='green')
# display the Polar plot
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
